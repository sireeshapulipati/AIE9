# %% [markdown]
# Now that you've deployed your endpoint - it's time to slam it!

# %%
import os
import getpass
from dotenv import load_dotenv

load_dotenv()

if not os.environ.get("FIREWORKS_API_KEY"):
    os.environ["FIREWORKS_API_KEY"] = getpass.getpass("Enter your Fireworks API key: ")

# %% [markdown]
# Let's try with 1 request, just to verify our endpoint is alive.
#
# Make sure you provide your own endpoint identifier! It will look something like this:
#
# - `accounts/fireworks/models/gpt-oss-20b` (serverless)
# - Or your custom on-demand deployment identifier

# %%
from langchain_fireworks import ChatFireworks

# REPLACE WITH YOUR OWN ENDPOINT IDENTIFIER
model_endpoint = "accounts/fireworks/models/gpt-oss-20b"

llm = ChatFireworks(model=model_endpoint)

response = llm.invoke("How much wood could a wood chuck chuck if a wood chuck could chuck wood?")
print(response.content)
# Out:
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x115628b90>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x11565ccd0>
# Ah the classic tongue‑twister!  In truth, no wood‑chuck (aka *Marmota monax*) has ever been observed actually “chucking” finished lumber – they’re more famous for moving soil than shoveling timber.  Still, the folklore answer that has survived the years is a blend of a little science, a lot of rhyme, and a generous dose of imagination.
#
# **The “scientific” estimate**
# In 1988, wildlife biologist Richard Thomas took a quick look at the earth‑moving habits of a typical wood‑chuck and, by an outside‑the‑box conversion, estimated that the creature could move **about 700 pounds** of material in a day.  That figure has since been recycled into the wood‑chuck‑tongue‑twister lore as the pseudo‑evidence that a wood‑chuck could chuck wood; the wording now reads:
#
# > *“A wood‑chuck would chuck as much wood as a wood‑chuck could, if a wood‑chuck could chuck wood.”*
#
# **What 700 pounds actually looks like**
# - Roughly 1 cubic yard of hardwood (e.g., oak or pine).
# - About 150 sticks, 12 inches long, 2 inches thick.
# - Or, if you prefer, a small branch‑bundle that would fill a medium‑sized jardinière.
#
# **A lighter, whimsical version**
# If we take the fun of the riddle literally, a wood‑chuck’s “chucking power” is limited only by its imagination – and its food supply.  A quick calculation based on a typical wood‑chuck’s bite rate (≈ 50 g of wood per bite) and a 10‑hour workday gives:
#
# \[
# \text{Wood per day} \;=\; 50\text{ g bite}\times \frac{1\text{ kg}}{850\text{ g}}\times 10\text{ h}\times 10\text{ bites/h}\approx 6\text{ kg}\;\approx\;13\text{ lb}
# \]
#
# That’s a surprisingly small chunk of forest, but a perfect “hundred‑pounds” answer for a playful tongue‑twister.
#
# **Bottom line**
# - **Folklore/Science‑based**: ~700 lb (1 yard³ of wood).
# - **Pun‑ready**: “A wood‑chuck would chuck as many wood‑chucks’ worth of wood as it could… if it could chuck wood!”
#
# So next time you’re spitting out the rhyme, consider that a wood‑chuck might have the ambition of a lumberjack, the power of a bulldozer, and the patience of a well‑fed rodent.  Happy chucking!

# %% [markdown]
# Now, let's SLAM IT.

# %%
import asyncio

async def send_request(llm, idx):
    try:
        response = await llm.ainvoke(
            f"How much wood could a wood chuck chuck if a wood chuck could chuck wood? (Request {idx})"
        )
        print(f"Response {idx}: {response.content[:60]}...")
    except Exception as e:
        print(f"Request {idx} failed: {e}")

async def main():
    tasks = [send_request(llm, i) for i in range(1, 25)]
    await asyncio.gather(*tasks)

await main()
# Out:
# Request 11 failed: {"error":{"message":"You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.","param":null,"code":"RATE_LIMIT_EXCEEDED","type":"error"},"request_id":"chatcmpl-d49fed1663c440999cd8124b2aee8b20"}
# Request 5 failed: {"error":{"message":"You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.","param":null,"code":"RATE_LIMIT_EXCEEDED","type":"error"},"request_id":"chatcmpl-4a5a795347a8497eb9b9a77d523b1c1b"}
# Request 9 failed: {"error":{"message":"You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.","param":null,"code":"RATE_LIMIT_EXCEEDED","type":"error"},"request_id":"chatcmpl-40512b56d9dc460d886978f58faef675"}
# Response 20: Approximately 700 pounds of wood....
# Response 1: The classic tongue‑twister has been taken as a jest rather t...
# Response 8: I’m not sure what “Request 8” refers to. Could you give me a...
# Response 22: Ah, the classic tongue‑twister! While there isn’t a definiti...
# Response 16: It’s really a tongue‑twister, but there’s a playful estimate...
# Response 21: The famous tongue‑twister turns the question from a light‑he...
# Response 18: It’s a classic tongue‑tapper, but if we really *did* try to ...
# Response 23: Ah, the age‑old riddle that has tickled tongues and tickled ...
# Response 7: A classic tongue‑twister, but let’s have a little fun with i...
# Response 17: A classic tongue‑twister, but if we try to give it a little ...
# Response 12: ### The classic tongue‑twister answer
#
# In 1988 wildlife biol...
# Response 6: A 1988 study by wildlife biologist Richard Thomas estimated ...
# Response 19: A classic tongue‑twister, indeed!
# In the spirit of the jok...
# Response 15: Request 15 – the classic wood‑chuck riddle:
#
# > **“How much ...
# Response 4: **Answer**
#
# The classic tongue‑twister lays it out for us:  ...
# Response 3: The classic tongue‑twister answer is the most accurate “scie...
# Response 10: Ah, the classic tongue‑twister turned woodland trivia questi...
# Response 13: **Short answer:**
# A wood‑chuck could chuck about **700 pou...
# Response 24: A woodchuck, if it could chuck wood, would chuck roughly 700...
# Response 2: **Answer (Request 2)**
#
# > *“How much wood could a woodchuc...
# Response 14: **Answer (the tongue‑twister, the science, and a sprinkle of...
